# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
data = pd.read_csv("datasets/2019_bikes.csv", low_memory = False)

# %%
data.head()
# Out:
#    Unnamed: 0      bike_id scrape_weekday     u_id        lat       lon  \
# 0           0        21664            Tue    34183  50.936540  6.948328
# 1           1        21619            Tue   672578  50.953946  6.912720
# 2           2  21802,22745            Tue   908905  50.944303  6.925402
# 3           3        22078            Tue  1307851  50.943650  6.933976
# 4           4        22370            Tue  1780485  50.954575  6.901232
#
#       scrape_datetime
# 0 2019-01-01 00:05:02
# 1 2019-01-01 00:05:02
# 2 2019-01-01 00:05:02
# 3 2019-01-01 00:05:02
# 4 2019-01-01 00:05:02

# %%
mixed_type_columns = data.columns[data.dtypes.apply(lambda x: str(x)).duplicated()]

print("Columns with mixed data types:")
print(mixed_type_columns)
# Out:
# Columns with mixed data types:
# Index(['scrape_weekday', 'u_id', 'lon'], dtype='object')

# %%
# Check the current data type
print(data['lon'].dtype)
# Out:
# float64

# %%
data['scrape_datetime'] = pd.to_datetime(data['scrape_datetime'], errors='coerce')

# %%
data['scrape_weekday'] = data['scrape_weekday'].astype(str)

# %%
data['lon'] = data['lon'].astype(float)

# %%
print(data['scrape_weekday'].dtype)
# Out:
# object

# %%
data_2018 = pd.read_csv("datasets/2018_bikes.csv", low_memory = False)

# %%
data_2018.head()
# Out:
#    Unnamed: 0 bike_id scrape_weekday    u_id        lat       lon  \
# 0           0   21157            Mon  380335  50.930298  6.974678
# 1           1   21595            Mon  382847  50.965378  6.953540
# 2           2   21487            Mon  429458  50.904353  6.928285
# 3           3   21326            Mon  430898  50.930544  6.972746
# 4           4   21762            Mon  431996  50.923605  6.966358
#
#        scrape_datetime
# 0  2018-01-01 00:00:03
# 1  2018-01-01 00:00:03
# 2  2018-01-01 00:00:03
# 3  2018-01-01 00:00:03
# 4  2018-01-01 00:00:03

# %%
data_bike = pd.read_csv("datasets/bike_data.csv")

# %%
data_bike.head()
# Out:
#    Unnamed: 0  tripduration                 starttime  \
# 0           1           222  2020-09-01 00:15:58.6470
# 1           2           193  2020-09-01 00:49:00.7370
# 2           3           273  2020-09-01 00:51:44.5870
# 3           4          1419  2020-09-01 00:52:48.3160
# 4           5           254  2020-09-01 00:56:16.7170
#
#                    stoptime  start.station.id start.station.name  \
# 0  2020-09-01 00:19:40.8750              3186      Grove St PATH
# 1  2020-09-01 00:52:14.3640              3640     Journal Square
# 2  2020-09-01 00:56:17.7160              3191           Union St
# 3  2020-09-01 01:16:28.0490              3203      Hamilton Park
# 4  2020-09-01 01:00:31.0870              3194    McGinley Square
#
#    start.station.latitude  start.station.longitude  end.station.id  \
# 0               40.719586               -74.043117            3276
# 1               40.733670               -74.062500            3206
# ...

# %%
mixed_type_columns = data_bike.columns[data_bike.dtypes.apply(lambda x: str(x)).duplicated()]

print("Columns with mixed data types:")
print(mixed_type_columns)
# Out:
# Columns with mixed data types:
# Index(['tripduration', 'stoptime', 'start.station.id', 'start.station.name',
#        'start.station.longitude', 'end.station.id', 'end.station.name',
#        'end.station.latitude', 'end.station.longitude', 'bikeid', 'usertype',
#        'birth.year', 'gender', 'age', 'log_trip', 'year'],
#       dtype='object')
